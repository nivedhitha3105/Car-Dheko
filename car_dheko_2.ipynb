# %%
import pandas as pd

# %%
data = pd.read_csv("car_dekho.csv")

# %%
data.head()
# Out:
#    it  body type      km  ownerNo      oem              model  modelYear  \
# 0   0  Hatchback  120000        2  Hyundai        Hyundai i20       2015
# 1   0  Hatchback   80000        2   Maruti     Maruti Celerio       2016
# 2   0  Hatchback   44392        1  Hyundai  Hyundai Grand i10       2017
# 3   0  Hatchback   40000        1   Maruti     Maruti Wagon R       2016
# 4   0      Sedan  150000        2  Hyundai      Hyundai Verna       2007
#
#    centralVariantId           variantName price  ...  Acceleration  \
# 0              1487         Asta 1.4 CRDi  5.10  ...          11.0
# 1              3982                VXI AT  3.20  ...          15.0
# 2              5602  1.2 Kappa Magna BSIV  4.20  ...          12.0
# 3              4319               AMT VXI  3.50  ...          18.0
# 4              1796                  CRDi  1.50  ...          11.0
#
#           Tyre Type Alloy Wheel Size No Door Numbers Cargo Volumn  \
# 0          Tubeless             16.0             5.0        295.0
# 1  Tubeless  Radial              NaN             5.0        235.0
# 2          Tubeless              NaN             5.0        256.0
# 3    Tubeless Tyres              NaN             5.0        180.0
# 4   Tubeless Radial             14.0             4.0        352.0
#
#   Gross Weight BoreX Stroke  Compression Ratio  Ground Clearance Unladen  \
# 0          NaN          NaN                NaN                       NaN
# 1       1250.0      73 X 82             11.0:1                       NaN
# 2          NaN          NaN                NaN                       NaN
# 3       1350.0      69 x 72                NaN                       NaN
# 4       1650.0      75 x 87             17.8:1                       NaN
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/used-car-details/used...
# 2  https://www.cardekho.com/buy-used-car-details/...
# 3  https://www.cardekho.com/used-car-details/used...
# 4  https://www.cardekho.com/used-car-details/used...
#
# [5 rows x 67 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   it                             8368 non-null   int64
#  1   body type                      8364 non-null   object
#  2   km                             8368 non-null   int64
#  3   ownerNo                        8368 non-null   int64
#  4   oem                            8368 non-null   object
#  5   model                          8368 non-null   object
#  6   modelYear                      8368 non-null   int64
#  7   centralVariantId               8368 non-null   int64
#  8   variantName                    8368 non-null   object
#  9   price                          8368 non-null   object
#  10  priceActual                    1670 non-null   float64
#  11  Registration Year              8316 non-null   float64
#  12  Insurance Validity             8364 non-null   object
#  13  Fuel Type                      8368 non-null   object
#  14  RTO                            7474 non-null   object
#  15  Ownership                      8336 non-null   object
#  16  Transmission                   8368 non-null   object
#  17  Year of Manufacture            8348 non-null   float64
#  18  Features                       8368 non-null   int64
#  19  Comfort & Convenience          8300 non-null   float64
#  20  Interior                       8291 non-null   float64
#  21  Exterior                       8278 non-null   float64
#  22  Safety                         8272 non-null   float64
#  23  Entertainment & Communication  7273 non-null   float64
#  24  Mileage                        8081 non-null   float64
#  25  Engine                         8364 non-null   float64
#  26  Max Power                      8308 non-null   object
#  27  Torque                         8308 non-null   object
#  28  Wheel Size                     5386 non-null   float64
#  29  Engine and Transmission        8365 non-null   float64
#  30  Color                          8365 non-null   object
#  31  Engine Type                    8073 non-null   object
#  32  Displacement                   8364 non-null   float64
#  33  Max Torque                     8308 non-null   object
#  34  No of Cylinder                 8337 non-null   float64
#  35  Values per Cylinder            8317 non-null   float64
#  36  Value Configuration            6153 non-null   object
#  37  Fuel Suppy System              6642 non-null   object
#  38  Turbo Charger                  7329 non-null   object
#  39  Super Charger                  6407 non-null   object
#  40  Dimensions & Capacity          8328 non-null   float64
#  41  Length                         8289 non-null   float64
#  42  Width                          8285 non-null   float64
#  43  Height                         8289 non-null   float64
#  44  Wheel Base                     8205 non-null   float64
#  45  Front Tread                    4810 non-null   float64
#  46  Rear Tread                     4798 non-null   float64
#  47  Kerb Weight                    8309 non-null   object
#  48  Miscellaneous                  8363 non-null   float64
#  49  Gear Box                       8262 non-null   object
#  50  Drive Type                     6809 non-null   object
#  51  Seating Capacity               8362 non-null   float64
#  52  Steering Type                  8113 non-null   object
#  53  Turning Radius                 6768 non-null   float64
#  54  Front Brake Type               8272 non-null   object
#  55  Rear Brake Type                8272 non-null   object
#  56  Top Speed                      4582 non-null   float64
#  57  Acceleration                   4857 non-null   float64
#  58  Tyre Type                      8291 non-null   object
#  59  Alloy Wheel Size               5386 non-null   float64
#  60  No Door Numbers                8357 non-null   float64
#  61  Cargo Volumn                   6775 non-null   float64
#  62  Gross Weight                   3827 non-null   float64
#  63  BoreX Stroke                   2405 non-null   object
#  64  Compression Ratio              1895 non-null   object
#  65  Ground Clearance Unladen       515 non-null    float64
#  66  car_links                      8368 non-null   object
# dtypes: float64(32), int64(6), object(29)
# memory usage: 4.3+ MB

# %%
data = data.drop(columns = 'it',axis = 1)

# %%
data['price'] = data['price'].str.replace(',', '')
data['price'] = data['price'].astype(float)

# %%
data['Registration Year'] = data['Registration Year'].fillna(data['Registration Year'].median())
data['Registration Year'] = data['Registration Year'].astype(int)

# %%
data['Year of Manufacture'].fillna(data['Year of Manufacture'].mean(), inplace=True)
data['Year of Manufacture'] = data['Year of Manufacture'].astype('int')

# %%
data['Comfort & Convenience'].fillna(data['Comfort & Convenience'].mean(), inplace=True)
data['Comfort & Convenience'] = data['Comfort & Convenience'].astype('int')

# %%
data['Interior'].fillna(data['Interior'].mean(), inplace=True)
data['Interior'] = data['Interior'].astype('int')

# %%
data['Exterior'].fillna(data['Exterior'].mean(), inplace=True)
data['Exterior'] = data['Exterior'].astype('int')

# %%
data['Safety'].fillna(data['Safety'].mean(), inplace=True)
data['Safety'] = data['Safety'].astype('int')

# %%
data['Entertainment & Communication'].fillna(data['Entertainment & Communication'].mean(), inplace=True)
data['Entertainment & Communication'] = data['Entertainment & Communication'].astype('int')

# %%
data['Mileage'] = data['Mileage'].astype('float')

# %%
data['Engine'].fillna(data['Engine'].mean(), inplace=True)
data['Engine'] = data['Engine'].astype('int')

# %%
data['Wheel Size'].fillna(data['Wheel Size'].mean(), inplace=True)
data['Wheel Size'] = data['Wheel Size'].astype('int')

# %%
data['Engine and Transmission'].fillna(data['Engine and Transmission'].mean(), inplace=True)
data['Engine and Transmission'] = data['Engine and Transmission'].astype('int')

# %%
data['Displacement'].fillna(data['Displacement'].mean(),inplace = True)
data['Displacement'] = data['Displacement'].astype('int')

# %%
data['No of Cylinder'].fillna(data['No of Cylinder'].mean(),inplace = True)
data['No of Cylinder'] = data['No of Cylinder'].astype('int')

# %%
data['Values per Cylinder'].fillna(data['Values per Cylinder'].mean(),inplace = True)
data['Values per Cylinder'] = data['Values per Cylinder'].astype('int')

# %%
data['Dimensions & Capacity'].fillna(data['Dimensions & Capacity'].mean(),inplace = True)
data['Dimensions & Capacity'] = data['Dimensions & Capacity'].astype('int')

# %%
data['Length'] = data['Length'].fillna(0).astype(int)
data['Length'] = data['Length'].astype('int')

# %%
data['Width'] = data['Width'].fillna(0).astype(int)
data['Width'] = data['Width'].astype('int')

# %%
data['Height'] = data['Height'].fillna(0).astype(int)
data['Height'] = data['Height'].astype('int')

# %%
data['Wheel Base'] = data['Wheel Base'].fillna(0).astype(int)
data['Wheel Base'] = data['Wheel Base'].astype('int')

# %%
data['Front Tread'] = data['Front Tread'].fillna(0).astype(int)
data['Front Tread'] = data['Front Tread'].astype('int')

# %%
data['Rear Tread'] = data['Rear Tread'].fillna(0).astype(int)
data['Rear Tread'] = data['Rear Tread'].astype('int')

# %%
data['Miscellaneous'].fillna(data['Miscellaneous'].mean(),inplace = True)
data['Miscellaneous'] = data['Miscellaneous'].astype('int')

# %%
data['Seating Capacity'].fillna(data['Seating Capacity'].mean(),inplace = True)
data['Seating Capacity'] = data['Seating Capacity'].astype('int')

# %%
data['Top Speed'] = data['Top Speed'].fillna(0).astype(float)
data['Top Speed'] = data['Top Speed'].astype('float')

# %%
data['Turning Radius'] = data['Turning Radius'].fillna(0).astype(float)
data['Turning Radius'] = data['Turning Radius'].astype('float')

# %%
data['Acceleration'] = data['Acceleration'].fillna(0).astype(float)
data['Acceleration'] = data['Acceleration'].astype('float')

# %%
data['Alloy Wheel Size'].fillna(data['Alloy Wheel Size'].mean(),inplace = True)
data['Alloy Wheel Size'] = data['Alloy Wheel Size'].astype('int')

# %%
data['No Door Numbers'].fillna(data['No Door Numbers'].mean(),inplace = True)
data['No Door Numbers'] = data['No Door Numbers'].astype('int')

# %%
data['Cargo Volumn'].fillna(data['Cargo Volumn'].mean(),inplace = True)
data['Cargo Volumn'] = data['Cargo Volumn'].astype('int')

# %%
data['Gross Weight'].fillna(data['Gross Weight'].mean(),inplace = True)
data['Gross Weight'] = data['Gross Weight'].astype('int')

# %%
data['Ground Clearance Unladen'].fillna(data['Ground Clearance Unladen'].mean(),inplace = True)
data['Ground Clearance Unladen'] = data['Ground Clearance Unladen'].astype('int')

# %%
data = data.drop(columns = 'car_links',axis = 1)

# %%
data.isnull().sum()
# Out:
# body type                      4
# km                             0
# ownerNo                        0
# oem                            0
# model                          0
#                             ...
# Cargo Volumn                   0
# Gross Weight                   0
# BoreX Stroke                5963
# Compression Ratio           6473
# Ground Clearance Unladen       0
# Length: 65, dtype: int64

# %%
data = data.drop(columns = ['body type','ownerNo','Insurance Validity','centralVariantId','priceActual',
                            'Values per Cylinder', 'Value Configuration','Fuel Type', 'Transmission',
                            'Features', 'Interior', 'Safety','Entertainment & Communication','Engine',
                            'Torque', 'Wheel Size', 'Engine and Transmission',
                            'Engine Type', 'Displacement', 'Max Torque', 'No of Cylinder',
                            'Fuel Suppy System', 'Turbo Charger', 'Super Charger','Max Power','RTO','Gear Box',
                            'Dimensions & Capacity', 'Length', 'Height',
                            'Front Tread', 'Rear Tread', 'Kerb Weight', 'Miscellaneous',
                            'Drive Type', 'Steering Type', 'Turning Radius', 'Front Brake Type',
                            'Rear Brake Type', 'Top Speed','Tyre Type',
                            'Alloy Wheel Size', 'No Door Numbers', 'Cargo Volumn', 'Gross Weight','Seating Capacity',
                            'BoreX Stroke', 'Compression Ratio','Ground Clearance Unladen'],axis = 1)

# %%
data.columns
# Out:
# Index(['km', 'oem', 'model', 'modelYear', 'variantName', 'price',
#        'Registration Year', 'Ownership', 'Year of Manufacture',
#        'Comfort & Convenience', 'Exterior', 'Mileage', 'Color', 'Width',
#        'Wheel Base', 'Acceleration'],
#       dtype='object')

# %%
data.to_csv("/Users/jainivedhitha/Desktop/project_data.csv")

# %%
data = pd.read_csv("project_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      km      oem              model  modelYear  \
# 0           0  120000  Hyundai        Hyundai i20       2015
# 1           1   80000   Maruti     Maruti Celerio       2016
# 2           2   44392  Hyundai  Hyundai Grand i10       2017
# 3           3   40000   Maruti     Maruti Wagon R       2016
# 4           4  150000  Hyundai      Hyundai Verna       2007
#
#             variantName  price  Registration Year Ownership  \
# 0         Asta 1.4 CRDi    5.1               2015    Second
# 1                VXI AT    3.2               2016    Second
# 2  1.2 Kappa Magna BSIV    4.2               2017     First
# 3               AMT VXI    3.5               2016     First
# 4                  CRDi    1.5               2007    Second
#
#    Year of Manufacture  Comfort & Convenience  Exterior  Mileage   Color  \
# 0                 2015                     17        12    22.54  Others
# 1                 2016                     10         5    23.10  Others
# 2                 2017                     13         8    18.90  Silver
# 3                 2016                     12        11    20.51  Silver
# 4                 2007                     11         5    16.80    Gray
#
#    Width  Wheel Base  Acceleration
# 0   1734        2570          11.0
# 1   1635        2425          15.0
# 2   1660        2425          12.0
# 3   1495        2400          18.0
# 4   1695        2500          11.0

# %% [markdown]
# # REMOVING NULL VALUES

# %%
data = data.drop(columns = ['Unnamed: 0'])

# %%
def impute_categorical(df):
    for column in df.select_dtypes(include=['object']).columns:
        df[column].fillna(df[column].mode()[0], inplace=True)
    return df

# Apply the function to your DataFrame
data = impute_categorical(data)

# %%
data.isnull().sum()
# Out:
# km                         0
# oem                        0
# model                      0
# modelYear                  0
# variantName                0
# price                      0
# Registration Year          0
# Ownership                  0
# Year of Manufacture        0
# Comfort & Convenience      0
# Exterior                   0
# Mileage                  287
# Color                      0
# Width                      0
# Wheel Base                 0
# Acceleration               0
# dtype: int64

# %%
import pandas as pd

def fill_na_numerical(data, method='mean'):

    for col in data.select_dtypes(include=['int64', 'float64']).columns:
        if method == 'mean':
            fill_value = data[col].mean()  # Compute mean
        elif method == 'median':
            fill_value = data[col].median()  # Compute median
        else:
            raise ValueError("Method must be either 'mean' or 'median'")

        data[col].fillna(fill_value, inplace=True)
    
    return data

data = fill_na_numerical(data, method='mean')

print(data.isnull().sum())
# Out:
# km                       0
# oem                      0
# model                    0
# modelYear                0
# variantName              0
# price                    0
# Registration Year        0
# Ownership                0
# Year of Manufacture      0
# Comfort & Convenience    0
# Exterior                 0
# Mileage                  0
# Color                    0
# Width                    0
# Wheel Base               0
# Acceleration             0
# dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# .

# %% [markdown]
# #  DESCRIPTIVE STATISTICS

# %%
data.describe()
# Out:
#                  km    modelYear         price  Registration Year  \
# count  8.368000e+03  8368.000000   8368.000000        8368.000000
# mean   5.897335e+04  2016.503824    889.136054        2016.615440
# std    7.406537e+04     3.921390   7915.440179           3.801085
# min    0.000000e+00  1985.000000      1.000000        2002.000000
# 25%    3.000000e+04  2014.000000      4.000000        2014.000000
# 50%    5.367450e+04  2017.000000      6.190000        2017.000000
# 75%    8.000000e+04  2019.000000      9.750000        2019.000000
# max    5.500000e+06  2023.000000  99703.000000        2023.000000
#
#        Year of Manufacture  Comfort & Convenience     Exterior      Mileage  \
# count          8368.000000            8368.000000  8368.000000  8368.000000
# mean           2016.547084              15.729207    10.747968    19.255467
# std               3.807321               6.377945     4.710978     3.961010
# min            2002.000000               1.000000     1.000000     7.080000
# 25%            2014.000000              11.000000     7.000000    17.010000
# 50%            2017.000000              15.000000    10.000000    19.020000
# 75%            2019.000000              20.000000    14.000000    21.400000
# max            2023.000000              37.000000    27.000000   140.000000
#
#              Width   Wheel Base  Acceleration
# count  8368.000000  8368.000000   8368.000000
# mean   1714.164794  2498.944790      7.220722
# std     213.874133   384.098768      6.670956
# min       0.000000     0.000000      0.000000
# 25%    1677.000000  2425.000000      0.000000
# 50%    1733.000000  2520.000000      9.000000
# 75%    1788.000000  2612.500000     13.000000
# max    2220.000000  3365.000000     44.000000

# %%
mode = data.mode().iloc[0]
mode
# Out:
# km                           120000
# oem                          Maruti
# model                    Honda City
# modelYear                      2018
# variantName                     VXI
# price                           6.5
# Registration Year              2017
# Ownership                     First
# Year of Manufacture            2018
# Comfort & Convenience            11
# Exterior                         12
# Mileage                        18.9
# Color                        Others
# Width                          1695
# Wheel Base                     2450
# Acceleration                    0.0
# Name: 0, dtype: object

# %% [markdown]
# # DATA VISULIZATIONS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.columns
# Out:
# Index(['km', 'oem', 'model', 'modelYear', 'variantName', 'price',
#        'Registration Year', 'Ownership', 'Year of Manufacture',
#        'Comfort & Convenience', 'Exterior', 'Mileage', 'Color', 'Width',
#        'Wheel Base', 'Acceleration'],
#       dtype='object')

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(5,5))
data['Year of Manufacture'].hist(bins=20,color = 'cyan')
plt.title('Histogram of Color')
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['Ownership'],color = 'darkorchid')
plt.title('Hist Plot of wheel Base')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=data, x='Registration Year', y='price',color = 'indianred')
plt.title('Price Distribution by Registration Year')
plt.xlabel('Registration Year')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(data=data, x='Ownership', y='price', estimator='mean',color = 'mediumturquoise')
plt.title('Average Price by Number of Owners')
plt.xlabel('Number of Owners')
plt.ylabel('Average Price')
plt.show()

# %%
plt.figure(figsize=(5,4))
average_price_per_year = data.groupby('modelYear')['price'].mean().reset_index()
sns.lineplot(data=average_price_per_year, x='modelYear', y='price',color = 'mediumvioletred')
plt.title('Average Price Over Model Years')
plt.xlabel('Model Year')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # CATEGORICAL AND NUMERICAL COLUMNS

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical Columns:", numerical_columns)


categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
print("Categorical Columns:", categorical_columns)
# Out:
# Numerical Columns: ['km', 'modelYear', 'price', 'Registration Year', 'Year of Manufacture', 'Comfort & Convenience', 'Exterior', 'Mileage', 'Width', 'Wheel Base', 'Acceleration']
# Categorical Columns: ['oem', 'model', 'variantName', 'Ownership', 'Color']

# %% [markdown]
# # LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
for col in categorical_columns:
    data[col] = label_encoder.fit_transform(data[col])

data.head()
# Out:
#        km  oem  model  modelYear  variantName  price  Registration Year  \
# 0  120000    9     90       2015          852    5.1               2015
# 1   80000   20    160       2016         1818    3.2               2016
# 2   44392    9     77       2017           95    4.2               2017
# 3   40000   20    184       2016          790    3.5               2016
# 4  150000    9     86       2007          917    1.5               2007
#
#    Ownership  Year of Manufacture  Comfort & Convenience  Exterior  Mileage  \
# 0          3                 2015                     17        12    22.54
# 1          3                 2016                     10         5    23.10
# 2          1                 2017                     13         8    18.90
# 3          1                 2016                     12        11    20.51
# 4          3                 2007                     11         5    16.80
#
#    Color  Width  Wheel Base  Acceleration
# 0     86   1734        2570          11.0
# 1     86   1635        2425          15.0
# 2    116   1660        2425          12.0
# 3    116   1495        2400          18.0
# 4     55   1695        2500          11.0

# %% [markdown]
# # REMOVAL OF OUTLIERS

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25) 
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1 
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR 
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
for column in numerical_columns:
    data = remove_outliers_iqr(data, column)

# %% [markdown]
# # CORRELATION HEATMAP

# %%
numerical_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation_matrix, annot=True, cmap='Spectral')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# OBSERVATION:
#
#     There are strong correlations between variables like Engine Type, Max Torque, Engine Displacement,Max Power         and Number of Cylinders. This makes sense as larger engines with more cylinders typically produce more power
#     and torque.
#
#     Wheelbase, Length, Width, and Height show strong correlations with each other, especially between Length and
#     Wheelbase with a correlation of 0.94, which indicates that larger cars tend to have longer wheelbases.
#
#     A notable negative correlation exists between Price and No. of Owners (-0.36) which indicates that cars with
#     multiple owners tend to be cheaper.
#
#     Also, Age of the car and Price are negatively correlated (-0.35), suggesting that older cars are cheaper,
#     which is expected in used car markets.

# %% [markdown]
# # FEATURE SELECTION USING RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = data.drop('price', axis=1)
y = data['price']

# %%
model = RandomForestRegressor()
model.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
feature_importances = model.feature_importances_

# %%
features_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# %%
features_df = features_df.sort_values(by='Importance', ascending=False)

# %%
print("Feature Importances:\n", features_df)
# Out:
# Feature Importances:
#                    Feature  Importance
# 12                  Width    0.423594
# 13             Wheel Base    0.130200
# 7     Year of Manufacture    0.105273
# 3               modelYear    0.083001
# 8   Comfort & Convenience    0.052574
# 5       Registration Year    0.039861
# 9                Exterior    0.032092
# 0                      km    0.029104
# 4             variantName    0.024651
# 10                Mileage    0.024118
# 2                   model    0.020055
# 14           Acceleration    0.012814
# 11                  Color    0.011752
# 1                     oem    0.006375
# 6               Ownership    0.004536

# %%
plt.figure(figsize=(10,10))
bar_plot = sns.barplot(data=features_df, x='Importance', y='Feature', palette='viridis')
plt.title('Feature Importance')
for index, value in enumerate(features_df['Importance']):
    bar_plot.text(value + 0.005, index, f'{value*100:.2f}', va='center') 
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
data.columns
# Out:
# Index(['km', 'oem', 'model', 'modelYear', 'variantName', 'price',
#        'Registration Year', 'Ownership', 'Year of Manufacture',
#        'Comfort & Convenience', 'Exterior', 'Mileage', 'Color', 'Width',
#        'Wheel Base', 'Acceleration'],
#       dtype='object')

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
x = data.drop('price',axis =1)
y = data['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x)
# Out:
# MinMaxScaler()

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

joblib.dump(scaler, '/Users/jainivedhitha/Desktop/min_max_scaler.pkl')
# Out:
# ['/Users/jainivedhitha/Desktop/min_max_scaler.pkl']

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

cv_scores = cross_val_score(linear_model, x_train, y_train, cv=5, scoring='neg_mean_squared_error')

linear_model.fit(x_train, y_train)

y_pred = linear_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Linear Regression MSE: {mse}")
print(f"Cross-Validation MSE: {-cv_scores.mean()}")
# Out:
# Linear Regression MSE: 2.976451376616441
# Cross-Validation MSE: 3.211030885463468

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_model = DecisionTreeRegressor(random_state=42)

# %%
param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

# %%
grid_search_tree = GridSearchCV(tree_model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search_tree.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
best_tree_model = grid_search_tree.best_estimator_

# %%
y_pred_tree = best_tree_model.predict(x_test)
mse_tree = mean_squared_error(y_test, y_pred_tree)
print(f"Decision Tree MSE: {mse_tree}")
print(f"Best Parameters: {grid_search_tree.best_params_}")
# Out:
# Decision Tree MSE: 1.893748101416243
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20}

# %% [markdown]
# # GRADIENT BOOSTING ALGORITHM

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr_model = GradientBoostingRegressor(random_state=42)

# %%
param_grid_gbr = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 10],
    'subsample': [0.8, 1.0]
}

# %%
grid_search_gbr = GridSearchCV(gbr_model, param_grid_gbr, cv=5, scoring='neg_mean_squared_error')
grid_search_gbr.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]},
#              scoring='neg_mean_squared_error')

# %%
best_gbr_model = grid_search_gbr.best_estimator_

# %%
y_pred_gbr = best_gbr_model.predict(x_test)
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
print(f"Gradient Boosting MSE: {mse_gbr}")
print(f"Best Parameters: {grid_search_gbr.best_params_}")
# Out:
# Gradient Boosting MSE: 1.106166325606413
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'subsample': 1.0}

# %% [markdown]
# # MODEL EVALUATION:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"R-squared (R2): {r2}")
    print("\n")

# %%
print("Linear Regression Performance:")
y_pred_linear = linear_model.predict(x_test)
lr_eval = evaluate_model(y_test, y_pred_linear)
lr_eval
# Out:
# Linear Regression Performance:
# Mean Absolute Error (MAE): 1.2345537841003558
# Mean Squared Error (MSE): 2.976451376616441
# R-squared (R2): 0.7439890727978422

# %%
print("Decision Tree Performance:")
y_pred_tree = best_tree_model.predict(x_test)
dt_eval = evaluate_model(y_test, y_pred_tree)
dt_eval
# Out:
# Decision Tree Performance:
# Mean Absolute Error (MAE): 0.9412537682483327
# Mean Squared Error (MSE): 1.893748101416243
# R-squared (R2): 0.8371146892773937

# %%
print("Gradient Boosting Performance:")
y_pred_gbr = best_gbr_model.predict(x_test)
gb_eval = evaluate_model(y_test, y_pred_gbr)
gb_eval
# Out:
# Gradient Boosting Performance:
# Mean Absolute Error (MAE): 0.7365990745768153
# Mean Squared Error (MSE): 1.106166325606413
# R-squared (R2): 0.9048562765435711

# %% [markdown]
# # REGULARIZATION

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# LASSO REGULARIZATION

# %%
lasso = Lasso()
params_lasso = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]} 
lasso_grid = GridSearchCV(lasso, params_lasso, cv=5, scoring='neg_mean_squared_error')
lasso_grid.fit(x_train, y_train)

best_lasso_model = lasso_grid.best_estimator_
print("Best Lasso Model:", best_lasso_model)

y_pred_lasso = best_lasso_model.predict(x_test)
lasso_eval = evaluate_model(y_test, y_pred_lasso)
lasso_eval
# Out:
# /Users/jainivedhitha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.038e+01, tolerance: 4.935e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/jainivedhitha/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.106e+00, tolerance: 5.000e+00
#   model = cd_fast.enet_coordinate_descent(
# Best Lasso Model: Lasso(alpha=0.001)
# Mean Absolute Error (MAE): 1.2345052169590622
# Mean Squared Error (MSE): 2.9763092407871676
# R-squared (R2): 0.7440012982034803

# %% [markdown]
# RIDGE OR L2 REGULARIZATION

# %%
ridge = Ridge()
params_ridge = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]} 
ridge_grid = GridSearchCV(ridge, params_ridge, cv=5, scoring='neg_mean_squared_error')
ridge_grid.fit(x_train, y_train)

best_ridge_model = ridge_grid.best_estimator_
print("Best Ridge Model:", best_ridge_model)

y_pred_ridge = best_ridge_model.predict(x_test)
ridge_eval = evaluate_model(y_test, y_pred_ridge)
ridge_eval
# Out:
# Best Ridge Model: Ridge(alpha=100)
# Mean Absolute Error (MAE): 1.234424105692575
# Mean Squared Error (MSE): 2.9764005382910463
# R-squared (R2): 0.7439934455105712

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace these lists with actual metrics from your models
models = ["Linear Regression", "Decision Tree", "Gradient Boosting", "Lasso Regression", "Ridge Regression"]
mae_values = [1.23,0.94,0.73,1.23,1.23]  # Replace with actual MAE values
mse_values = [2.97,1.89,1.10,2.97,2.97]  # Replace with actual MSE values
r2_values = [0.74,0.83,0.91,0.74,0.74]  # Replace with actual R² values

# Set up the plot
x = np.arange(len(models))  # the label locations
width = 0.25  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))

# Plot each metric
bars1 = ax.bar(x - width, mae_values, width, label="MAE", color="skyblue")
bars2 = ax.bar(x, mse_values, width, label="MSE", color="salmon")
bars3 = ax.bar(x + width, r2_values, width, label="R2 Score", color="lightgreen")

# Labeling and titles
ax.set_xlabel("Models")
ax.set_ylabel("Metric Values")
ax.set_title("Comparison of MAE, MSE, and R2 Scores Across Models")
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

# Rotate x labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import joblib

save_path = '/Users/jainivedhitha/Desktop/car_model.pkl'  # Specify the full path
joblib.dump(best_gbr_model, save_path)

print(f"Model saved at: {save_path}")
# Out:
# Model saved at: /Users/jainivedhitha/Desktop/car_model.pkl
